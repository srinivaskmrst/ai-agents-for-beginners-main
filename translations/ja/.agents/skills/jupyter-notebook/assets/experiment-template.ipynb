# %% [markdown]
# # 実験: TITLE
#
# 目的:
# - 回答したい質問を記述してください。
# - 成功基準を定義してください。

# %%
# Setup: imports and reproducibility
from __future__ import annotations

import random
import statistics

SEED = 7
random.seed(SEED)
SEED

# %% [markdown]
# ## 計画
#
# - 仮説:
# - スイープする変数:
# - 記録する指標:

# %%
# Define parameters and lightweight helpers
sample_size = 20
values = [random.random() for _ in range(sample_size)]
summary = {
    "count": len(values),
    "mean": statistics.fmean(values),
    "min": min(values),
    "max": max(values),
}
summary

# %% [markdown]
# ## 結果
#
# - 主な観察事項:
# - 驚きや失敗モード:
# - 決定: 続行、方向転換、または中止:

# %%
# Record findings in a minimal, copy-pasteable structure
result = {
    "seed": SEED,
    "mean": summary["mean"],
    "range": summary["max"] - summary["min"],
}
result

# %% [markdown]
# ## 次のステップ
#
# - 次に試すこと：
# - 別の場所に記録すること（PRD、ノート、課題）：

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# 免責事項：
# 本書はAI翻訳サービス「[Co-op Translator](https://github.com/Azure/co-op-translator)」を使用して翻訳されました。正確性の確保に努めておりますが、自動翻訳には誤りや不正確な箇所が含まれる可能性があります。原文（原言語）の文書を正本とみなしてください。重要な情報については、専門の人間による翻訳を推奨します。本翻訳の利用により生じた誤解や解釈の相違について、当方は一切責任を負いません。
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
