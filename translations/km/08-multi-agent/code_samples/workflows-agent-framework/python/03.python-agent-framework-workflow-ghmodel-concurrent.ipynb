# %% [markdown]
# # ⚡ កម្មវិធីបំពេញការងារផ្សេងៗរួមគ្នារបស់ភ្នាក់ងារ ជាមួយ GitHub Models (Python)
#
# ## 📋 មេរៀន​កម្រិតខ្ពស់​អំពី​ការ​ដំណើរការ​ពហុស្រប
#
# កំណត់ត្រានេះបង្ហាញពី **ទម្រង់រៀបចំ workflow សម័យស្រប** ដោយប្រើ Microsoft Agent Framework។ អ្នកនឹងរៀនរបៀបកសាង workflow ដំណើរការភាពល្អខ្ពស់ និងពហុស្រប ដែលភ្នាក់ងារ AI ជាច្រើនអនុវត្តក្នុងពេលតែមួយ កើនឡើងសមត្ថភាព throughput ដ៏ចម្រាស់ ហើយអនុញ្ញាតដល់ដំណើរការអាជីវកម្មពហុខ្សែដ៏ស្មុគស្មាញ។
#
# ## 🎯 គោលដៅការរៀន
#
# ### 🚀 **មូលដ្ឋាននៃការដំណើរការសម័យស្រប**
# - **ការអនុវត្តភ្នាក់ងារពហុស្រប**: រត់ភ្នាក់ងារច្រើនក្នុងពេលតែមួយ សម្រាប់ប្រសិទ្ធភាពអតិបរមា
# - **Workflow Orchestration**: សម្របសម្រួលប្រតិបត្តិការសម័យស្រប ខណៈរក្សាសមភាពទិន្នន័យ
# - **ការបង្កើនប្រសិទ្ធភាព**: សម្រេចបានល្បឿនឡើងយ៉ាងសំខាន់តាមរយៈការដំណើរការពហុស្រប
# - **ការគ្រប់គ្រងធនធាន**: ប្រើប្រាស់ធនធានម៉ូដែល AI យ៉ាងមានប្រសិទ្ធភាពក្នុងប្រតិបត្តិការសម័យស្រប
#
# ### 🏗️ **គំរូពហុភាពកម្រិតខ្ពស់**
# - **Fork-Join Processing**: ផែការងារទៅឲ្យភ្នាក់ងារច្រើន ហើយរួមបញ្ចូលលទ្ធផលវិញ
# - **Pipeline Parallelism**: ការអនុវត្តដំណាក់កាលផ្ទិតផ្ទាល់គ្នា ដើម្បីធានា throughput បន្ត
# - **Load Balancing**: តម្រៀបបង់បញ្ជការងារ ឲ្យស្មើគ្នាលើធនធានភ្នាក់ងារដែលមាន
# - **Synchronization Points**: ចុចធ្វើសមកម្មភាពភ្នាក់ងារសម័យស្របនៅដំណាក់កាលសំខាន់ៗនៃ workflow
#
# ### 🏢 **កម្មវិធីសម័យស្របសម្រាប់សហគ្រាស**
# - **High-Volume Document Processing**: ដំណើរការឯកសារច្រើននៅក្នុងពេលតែមួយ
# - **Real-Time Content Analysis**: វិភាគមាតិកាក្នុងពេលពិត: វិភាគស្របពេលនៃប្រភពទិន្នន័យដែលចូល
# - **Batch Processing Optimization**: បង្កើន throughput ឲ្យអតិបរមារសម្រាប់ប្រតិបត្តិការរង្វង់ធំ
# - **Multi-Modal Analysis**: ដំណើរការពហុស្របលើប្រភេទមាតិកាតែងផ្សេងៗ (text, images, data)
#
# ## ⚙️ ការទាមទារ និង ការតំឡើង
#
# ### 📦 **ការពឹងផ្អែកដែលទាមទារ**
#
# Install Agent Framework with concurrent workflow capabilities:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **ការកំណត់បរិយាកាស (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **ការពិចារណាអំពីការដំណើរការសម័យស្រប:**
# - **Rate Limits**: តាមដានកំណត់អត្រា API របស់ GitHub Models សម្រាប់សំណើសម័យស្រប
# - **Resource Usage**: ពិចារណាអំពីការប្រើប្រាស់ចងចាំ និង CPU នៅពេលមានភ្នាក់ងារសម័យស្របច្រើន
# - **Error Handling**: អនុវត្តយុទ្ធសាស្រ្តសង្រ្កោះកំហុសយ៉ាងរឹងមាំសម្រាប់ប្រតិបត្តិការពហុស្រប
#
# ### 🏗️ **ស្ថាបត្យកម្ម Workflow សម័យស្រប**
#
# ```mermaid
# graph TD
#     A[ចាប់ផ្តើមលំហូរការងារ] --> B[ការអនុវត្តរួម]
#     B --> C[ក្រុមភ្នាក់ងារ 1]
#     B --> D[ក្រុមភ្នាក់ងារ 2]
#     B --> E[ក្រុមភ្នាក់ងារ 3]
#     C --> F[ការសរុបលទ្ធផល]
#     D --> F
#     E --> F
#     F --> G[លទ្ធផលចុងក្រោយ]
#
#     H[API ម៉ូដែល GitHub] --> C
#     H --> D
#     H --> E
# ```
# **អត្ថប្រយោជន៍សំខាន់ៗ:**
# - **⚡ សមត្ថភាព**: ល្បឿនបានធ្វើឡើងយ៉ាងច្បាស់តាមរយៈការអនុវត្តពហុស្រប
# - **📈 Scalability**: អាចដោះស្រាយទម្រង់កម្មវិធីដែលមានទម្ងន់កើនឡើងដោយមិនបណ្តាលឲ្យពេលសមាហរណ៍កើនស្មើ
# - **🔄 ប្រសិទ្ធភាព**: ប្រើប្រាស់ធនធានគណនា​ដែលមានយ៉ាងមានប្រសិទ្ធភាព
# - **🎯 Throughput**: ដំណើរការការងារច្រើនឡើងក្នុងពេលដដែល
#
# ## 🎨 **គំរូរចនាដំណើរការសម័យស្រប**
#
# ### 🔍 **បណ្តាញស្រាវជ្រាវ និងវិភាគ**
# ```
# Research Task → Parallel Research Agents → Content Synthesis → Quality Review
# ```
#
# ### 📊 **លំហូរដំណើរការទិន្នន័យ**
# ```
# Input Data → Concurrent Processing Agents → Result Aggregation → Final Report
# ```
#
# ### 🎭 **បណ្តាញបង្កើតមាតិកា**
# ```
# Content Brief → Parallel Content Generators → Review & Merge → Final Content
# ```
#
# ### 🔄 **ការដំណើរការជាច្រើនដំណាក់កាល**
# ```
# Input → Stage 1 (Concurrent) → Stage 2 (Concurrent) → Stage 3 (Sequential) → Output
# ```
#
# ## 🏢 **អត្ថប្រយោជន៍ប្រសិទ្ធភាពសម្រាប់សហគ្រាស**
#
# ### ⚡ **ការបង្កើន Throughput**
# - **Parallel Execution**: ភ្នាក់ងារច្រើនធ្វើការនៅពេលតែមួយ
# - **Resource Utilization**: ប្រសិទ្ធភាពអតិបរមានៃកម្រិតម៉ូដែល AI ដែលមាន
# - **Time Reduction**: ការធ្លាក់ចុះយ៉ាងខ្លាំងក្នុងពេលសរុបនៃការដំណើរការ
# - **Scalable Architecture**: អាចបន្ថែមភ្នាក់ងារសម័យស្របបានយ៉ាងងាយស្រួលតាមតម្រូវការ
#
# ### 🛡️ **ការជឿទុកចិត្ត និងភាពធន់ទ្រាំ**
# - **Fault Tolerance**: ការខូចខាតក្នុងភ្នាក់ងារផ្ទាល់មិនឈប់ពីលំហូរការងារទាំងមូល
# - **Error Isolation**: បញ្ហាក្នុងសាខាមួយមិនប៉ះពាល់ដល់សាខាផ្សេងទេ
# - **Graceful Degradation**: ប្រព័ន្ធនៅតែបន្តធ្វើការ ទោះបីមានកម្រិតភ្នាក់ងារតិចជាងមុនក៏ដោយ
# - **Recovery Mechanisms**: សាកល្បងឡើងវិញដោយស្វ័យប្រវត្តិ និងចាត់ចੰਗកំហុសសម្រាប់ប្រតិបត្តិការដែលបរាជ័យ
#
# ### 📊 **ការត្រួតពិនិត្យ និងការមើលឃើញ**
# - **Concurrent Execution Tracking**: ត្រួតពិនិត្យដំណើរការនៃប្រតិបត្តិការពហុស្របទាំងអស់
# - **Performance Metrics**: វាស់ល្បឿនកើនឡើង និងផលចំណេញប្រសិទ្ធភាព
# - **Resource Usage Analytics**: វិភាគការប្រើធនធាន ដើម្បីប្រសើរឡើងការចែកចាយភ្នាក់ងារសម័យស្រប
# - **Bottleneck Identification**: រកឃើញ និងដោះស្រាយកន្លែងរាំងស្ទះនៃសមត្ថភាព
#
# តោះ! យើងចាប់ផ្តើមសាងសង់ workflow AI សម័យស្របដែលមានកម្រិតខ្ពស់! 🚀

# %%
! pip install agent-framework-core -U

# %%
import os
from typing import Any

from agent_framework import ChatMessage, ConcurrentBuilder,WorkflowViz
from agent_framework.openai import OpenAIChatClient

# %%
chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id="gpt-4o" )

# %%
ResearcherAgentName = "Researcher-Agent"
ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction."

# %%
PlanAgentName = "Plan-Agent"
PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings."

# %%
research_agent   = chat_client.create_agent(
        instructions=(
           ResearcherAgentInstructions
        ),
        name=ResearcherAgentName,
    )

plan_agent = chat_client.create_agent(
        instructions=(
            PlanAgentInstructions
        ),
        name=PlanAgentName,
    )

# %%
workflow = ConcurrentBuilder().participants([research_agent, plan_agent]).build()

# %%
print("Generating workflow visualization...")
viz = WorkflowViz(workflow)
# Print out the mermaid string.
print("Mermaid string: \n=======")
print(viz.to_mermaid())
print("=======")
# Print out the DiGraph string.
print("DiGraph string: \n=======")
print(viz.to_digraph())
print("=======")
svg_file = viz.export(format="svg")
print(f"SVG file saved to: {svg_file}")
# Out:
# Generating workflow visualization...
# Mermaid string:
# ...
# flowchart TD
#   dispatcher["dispatcher (Start)"];
#   Researcher_Agent["Researcher-Agent"];
#   Plan_Agent["Plan-Agent"];
#   aggregator["aggregator"];
#   fan_in__aggregator__69d73de8((fan-in))
#   Plan_Agent --> fan_in__aggregator__69d73de8;
#   Researcher_Agent --> fan_in__aggregator__69d73de8;
#   fan_in__aggregator__69d73de8 --> aggregator;
#   dispatcher --> Researcher_Agent;
#   dispatcher --> Plan_Agent;
# ...
# DiGraph string:
# ...
# digraph Workflow {
#   rankdir=TD;
#   node [shape=box, style=filled, fillcolor=lightblue];
#   edge [color=black, arrowhead=vee];
#
#   "dispatcher" [fillcolor=lightgreen, label="dispatcher\n(Start)"];
#   "Researcher-Agent" [label="Researcher-Agent"];
#   "Plan-Agent" [label="Plan-Agent"];
#   "aggregator" [label="aggregator"];
#
#   "fan_in::aggregator::69d73de8" [shape=ellipse, fillcolor=lightgoldenrod, label="fan-in"];
#   "Plan-Agent" -> "fan_in::aggregator::69d73de8";
# ...

# %%
from IPython.display import SVG, display, HTML
import os

print(f"Attempting to display SVG file at: {svg_file}")

if svg_file and os.path.exists(svg_file):
    try:
        # Preferred: direct SVG rendering
        display(SVG(filename=svg_file))
    except Exception as e:
        print(f"⚠️ Direct SVG render failed: {e}. Falling back to raw HTML.")
        try:
            with open(svg_file, "r", encoding="utf-8") as f:
                svg_text = f.read()
            display(HTML(svg_text))
        except Exception as inner:
            print(f"❌ Fallback HTML render also failed: {inner}")
else:
    print("❌ SVG file not found. Ensure viz.export(format='svg') ran successfully.")
# Out:
# Attempting to display SVG file at: C:\Users\kinfeylo\AppData\Local\Temp\tmpoq68cqjk.svg

# %%
events = await workflow.run("Plan a trip to Seattle in December")
outputs = events.get_outputs()

# %%
if outputs:
        print("===== Final Aggregated Conversation (messages) =====")
        for output in outputs:
            messages: list[ChatMessage] | Any = output
            for i, msg in enumerate(messages, start=1):
                name = msg.author_name if msg.author_name else "user"
                print(f"{'-' * 60}\n\n{i:02d} [{name}]:\n{msg.text}")
# Out:
# ===== Final Aggregated Conversation (messages) =====
# ------------------------------------------------------------
#
# 01 [user]:
# Plan a trip to Seattle in December
# ------------------------------------------------------------
#
# 02 [Researcher-Agent]:
# Seattle is a wonderful place to visit in December, with vibrant winter festivities, seasonal attractions, and gorgeous views of the Pacific Northwest. Despite the chilly weather and occasional rain, Seattle’s charm shines through its indoor and outdoor attractions. Here's a detailed plan for your trip:
#
# ---
#
# ### **Destination Overview: Seattle in December**
# - **Weather**: Expect average highs of around 47°F (8°C) and lows near 37°F (3°C). Rain is frequent, so bring waterproof clothing.
# - **Packing List**:
#   - Warm layers (sweaters, coats, gloves, and hats).
#   - Comfortable walking shoes (water-resistant is ideal).
#   - Umbrella or rain jacket.
#
# ---
#
# ### **Day 1: Exploring Downtown Seattle**
# ...

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **Disclaimer**:
# ឯកសារនេះត្រូវបានបកប្រែដោយប្រើសេវាបកប្រែដោយបញ្ញាសិប្បនិម្មិត [Co-op Translator](https://github.com/Azure/co-op-translator). បើទោះបីជា​យើងព្យាយាមធានា​ភាពត្រឹមត្រូវ សូមចំណាំថា ការបកប្រែដោយស្វ័យប្រវត្តិអាចមានកំហុស ឬមានព័ត៌មានដែលមិនត្រឹមត្រូវ។ ឯកសារដើមនៅក្នុងភាសាដើមគួរត្រូវបានចាត់ទុកជាប្រភពផ្លូវការ។ សម្រាប់ព័ត៌មានសំខាន់ យើងណែនាំឱ្យប្រើការបកប្រែដោយអ្នកជំនាញមនុស្សវិជ្ជាជីវៈ។ យើងមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកស្រាយខុសណាមួយដែលកើតមានពីការប្រើប្រាស់ការបកប្រែនេះទេ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
