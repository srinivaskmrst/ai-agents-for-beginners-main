# %% [markdown]
# # មេរៀន: TITLE
#
# Audience:
# - ពន្យល់ថាវាសម្រាប់នរណា។
#
# Prerequisites:
# - រាយបញ្ជីគំនិត ឬការតំឡើងដែលទាមទារ។
#
# Learning goals:
# - នៅចប់ អ្នកអានអាច...

# %% [markdown]
# ## សេចក្តីសង្ខេប
#
# 1. ការរៀបចំ
# 2. ឧទាហរណ៍តូចដែលអាចដំណើរការ
# 3. បម្លែង និងចំណុចដែលត្រូវប្រុងប្រយ័ត្ន
# 4. លំហាត់

# %%
# Setup cell: keep it short and deterministic
from __future__ import annotations

import math
import random

SEED = 21
random.seed(SEED)
SEED

# %% [markdown]
# ## ជំហានទី 1 - ចាប់ផ្តើមជាមួយឧទាហរណ៍តូច
#
# ពិពណ៌នាថាតើកោសិកាបន្ទាប់ធ្វើអ្វីដោយភាសាសាមញ្ញ។

# %%
# Minimal working example
angles = [0, math.pi / 4, math.pi / 2]
sines = [math.sin(a) for a in angles]
list(zip(angles, sines))

# %% [markdown]
# ## លំហាត់
#
# - សាកល្បងបញ្ចូលទិន្នន័យផ្សេង.
# - ទាយលទ្ធផលមុនពេលរត់កូដ.
# - ចំណាំកំហុសទូទៅមួយ និងវិធីជួសជុលវា.

# %%
# Exercise answer scaffold
def describe(values: list[float]) -> dict[str, float]:
    return {"min": min(values), "max": max(values)}

describe(sines)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការមិនទទួលខុសត្រូវ**:
# ឯកសារនេះត្រូវបានបកប្រែដោយប្រើសេវាកម្មបកប្រែដោយ AI [Co-op Translator](https://github.com/Azure/co-op-translator). ទោះយ៉ាងណា យើងខិតខំរកភាពត្រឹមត្រូវ សូមចំណាំថា ការបកប្រែដោយស្វ័យប្រវត្តិអាចមានកំហុស ឬ មិនត្រឹមត្រូវ។ ឯកសារដើមដែលសរសេរជាភាសាដើមគួរត្រូវបានចាត់ទុកថាជាឯកសារយោង។ សម្រាប់ព័ត៌មានសំខាន់ៗ យើងណែនាំឲ្យប្រើការបកប្រែដោយអ្នកជំនាញ។ យើងមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកអត្ថន័យខុសដែលបណ្តាលមកពីការប្រើប្រាស់ការបកប្រែនេះ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
